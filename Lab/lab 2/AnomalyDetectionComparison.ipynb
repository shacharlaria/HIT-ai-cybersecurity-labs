# %% [markdown]
# # Lab 2 — Isolation Forest vs Autoencoder with Embeddings
#
# This notebook provides a self-contained login-anomaly example aligned with the lecture:
#
# - **Isolation Forest** detects rare feature-space outliers.
# - **Autoencoder with embeddings** learns normal behavioral combinations.
# - The final section compares the models and inspects disagreements.
#
# The synthetic scenario is related to **MITRE ATT&CK T1078 (Valid Accounts)** and **T1110 (Brute Force)**.
#
#
# > **Interpretation guidance:** Explanatory comments are included after each results section to help connect the metrics and visualizations to SOC decision-making.

# %%
import os
os.environ["KERAS_BACKEND"] = "torch"

import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report, confusion_matrix, precision_recall_fscore_support
)
from sklearn.decomposition import PCA

import keras
from keras import layers

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

print("Keras backend:", keras.backend.backend())
# Out:
# mkdir -p failed for path /home/jovyan/.cache/matplotlib: [Errno 13] Permission denied: '/home/jovyan/.cache/matplotlib'
# Matplotlib created a temporary cache directory at /tmp/matplotlib-79rro9oi because there was an issue with the default path ({configdir}); it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# Keras backend: torch

# %% [markdown]
# ## 1. Generate synthetic login telemetry
#
# Normal records follow stable user, device, country and working-hour patterns. Attack records introduce unusual combinations such as late-night access, new countries, unknown devices and repeated failures.

# %%
N_NORMAL = 3800
N_ATTACK = 160

users = ["analyst01", "analyst02", "finance01", "developer01", "admin01"]
usual_country = {
    "analyst01": "IL", "analyst02": "IL", "finance01": "IL",
    "developer01": "IL", "admin01": "IL"
}
usual_device = {
    "analyst01": "managed_laptop", "analyst02": "managed_laptop",
    "finance01": "managed_laptop", "developer01": "developer_workstation",
    "admin01": "admin_workstation"
}

rows = []
for _ in range(N_NORMAL):
    user = np.random.choice(users, p=[0.25, 0.20, 0.20, 0.25, 0.10])
    rows.append({
        "user": user,
        "country": usual_country[user],
        "device": usual_device[user],
        "protocol": np.random.choice(["HTTPS", "VPN", "SSH"], p=[0.60, 0.32, 0.08]),
        "hour": int(np.clip(np.random.normal(12.5, 2.5), 6, 21)),
        "failed_attempts": np.random.poisson(0.25),
        "distance_km": abs(np.random.normal(8, 12)),
        "session_minutes": max(1, np.random.gamma(3.5, 12)),
        "bytes_out_mb": max(0.1, np.random.lognormal(2.0, 0.6)),
        "is_attack": 0
    })

for _ in range(N_ATTACK):
    user = np.random.choice(users)
    rows.append({
        "user": user,
        "country": np.random.choice(["RU", "CN", "SG", "US", "DE"]),
        "device": np.random.choice(["unknown", "mobile", "unmanaged_laptop"]),
        "protocol": np.random.choice(["HTTPS", "VPN", "SSH"]),
        "hour": np.random.choice([0, 1, 2, 3, 4, 23]),
        "failed_attempts": np.random.randint(5, 18),
        "distance_km": np.random.uniform(800, 9000),
        "session_minutes": np.random.uniform(1, 20),
        "bytes_out_mb": np.random.lognormal(5.0, 0.7),
        "is_attack": 1
    })

df = pd.DataFrame(rows).sample(frac=1, random_state=SEED).reset_index(drop=True)
print(df.shape)
display(df.head())
display(df["is_attack"].value_counts().rename(index={0:"normal",1:"attack"}))
# Out:
# (3960, 10)
#           user country                 device protocol  hour  failed_attempts  \
# 0  developer01      IL  developer_workstation    HTTPS    14                1
# 1    analyst01      IL         managed_laptop    HTTPS    16                0
# 2    analyst02      IL         managed_laptop    HTTPS    15                0
# 3    analyst02      IL         managed_laptop    HTTPS    17                1
# 4    finance01      IL         managed_laptop      VPN    10                1
#
#    distance_km  session_minutes  bytes_out_mb  is_attack
# 0    13.948183       115.895930      7.137972          0
# 1    20.547952        54.179346     10.660855          0
# 2    28.135590        40.337349      5.276849          0
# 3    14.747003        56.774082      4.102999          0
# 4    14.617715        45.746867     20.057241          0
# is_attack
# normal    3800
# attack     160
# Name: count, dtype: int64

# %% [markdown]
# ## 2. Exploratory analysis

# %%
numeric_cols = [
    "hour", "failed_attempts", "distance_km",
    "session_minutes", "bytes_out_mb"
]
categorical_cols = ["user", "country", "device", "protocol"]

df[numeric_cols].hist(figsize=(12, 8), bins=30)
plt.tight_layout()
plt.show()

print(df.groupby("is_attack")[numeric_cols].median().T)
# Out:
# is_attack                0            1
# hour             12.000000     2.000000
# failed_attempts   0.000000    11.000000
# distance_km      10.033474  4408.577160
# session_minutes  37.992850     9.477511
# bytes_out_mb      7.469846   149.085696

# %% [markdown]
# ### How to interpret the exploratory results
#
# Use the histograms and the class-wise median table to identify which variables differ most between normal and attack events.
#
# - A strong shift in **failed attempts**, **distance**, **session duration**, or **outbound traffic** suggests that those variables contain useful anomaly evidence.
# - Similar medians do **not** mean that a feature is useless. An anomaly may be caused by a rare **combination** of otherwise normal values.
# - Because attacks are the minority class, overall accuracy would be misleading. Later comparisons therefore emphasize precision, recall, F1, false positives, and false negatives.
#
# **Question to ask:** Which features appear individually unusual, and which may only become suspicious when combined with user, device, country, or protocol?

# %% [markdown]
# ## 3. Shared train, validation and test split
#
# The autoencoder is trained only on normal training events. Labels are retained exclusively for evaluation and threshold analysis.

# %%
train_df, temp_df = train_test_split(
    df, test_size=0.40, stratify=df["is_attack"], random_state=SEED
)
val_df, test_df = train_test_split(
    temp_df, test_size=0.50, stratify=temp_df["is_attack"], random_state=SEED
)

normal_train_df = train_df[train_df["is_attack"] == 0].copy()
normal_val_df = val_df[val_df["is_attack"] == 0].copy()

print("Train:", train_df.shape, "Normal-only AE train:", normal_train_df.shape)
print("Validation:", val_df.shape, "Test:", test_df.shape)
# Out:
# Train: (2376, 10) Normal-only AE train: (2280, 10)
# Validation: (792, 10) Test: (792, 10)

# %% [markdown]
# ## 4. Model A — Isolation Forest

# %%
if_preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore", sparse_output=False), categorical_cols),
    ]
)

X_if_train = if_preprocessor.fit_transform(train_df[numeric_cols + categorical_cols])
X_if_test = if_preprocessor.transform(test_df[numeric_cols + categorical_cols])
y_test = test_df["is_attack"].to_numpy()

iso = IsolationForest(
    n_estimators=300,
    contamination=float(train_df["is_attack"].mean()),
    random_state=SEED,
    n_jobs=-1
)
iso.fit(X_if_train)

if_score = -iso.decision_function(X_if_test)
if_pred = (iso.predict(X_if_test) == -1).astype(int)

print(confusion_matrix(y_test, if_pred))
print(classification_report(y_test, if_pred, target_names=["Normal", "Attack"]))
# Out:
# [[759   1]
#  [  0  32]]
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       760
#       Attack       0.97      1.00      0.98        32
#
#     accuracy                           1.00       792
#    macro avg       0.98      1.00      0.99       792
# weighted avg       1.00      1.00      1.00       792

# %% [markdown]
# ### Reading the Isolation Forest output
#
# The confusion matrix follows this layout:
#
# | | Predicted normal | Predicted attack |
# |---|---:|---:|
# | **Actually normal** | True negatives | False positives |
# | **Actually attack** | False negatives | True positives |
#
# Interpret the classification report as follows:
#
# - **Attack precision:** among all alerts raised by Isolation Forest, how many were real attacks?
# - **Attack recall:** among all real attacks, how many were detected?
# - **Attack F1:** balance between precision and recall.
# - **False positives:** normal events that would unnecessarily consume analyst time.
# - **False negatives:** attacks that would remain undetected.
#
# Isolation Forest is especially effective when an event is isolated in the transformed feature space, for example an extreme distance, many failed attempts, or a rare combination of one-hot encoded categories.

# %% [markdown]
# ## 5. Model B — Autoencoder with categorical embeddings
#
# Each categorical field is mapped to a trainable embedding. The decoder reconstructs:
#
# - standardized numeric values using mean squared error;
# - each categorical field using a softmax output.
#
# The anomaly score combines numeric reconstruction error and categorical negative log likelihood.

# %%
# Numeric scaling
num_scaler = StandardScaler()
num_scaler.fit(normal_train_df[numeric_cols])

# Category encoders fitted on the full training partition, with an explicit unknown token
category_maps = {}
category_sizes = {}
for col in categorical_cols:
    values = sorted(train_df[col].astype(str).unique().tolist())
    category_maps[col] = {value: i + 1 for i, value in enumerate(values)}  # 0 = unknown
    category_sizes[col] = len(values) + 1

def prepare_ae_frame(frame):
    numeric = num_scaler.transform(frame[numeric_cols]).astype("float32")
    inputs = {"numeric": numeric}
    targets = {"numeric_out": numeric}
    for col in categorical_cols:
        indices = frame[col].astype(str).map(category_maps[col]).fillna(0).astype("int32").to_numpy()
        inputs[col] = indices
        targets[f"{col}_out"] = indices
    return inputs, targets

ae_train_inputs, ae_train_targets = prepare_ae_frame(normal_train_df)
ae_val_inputs, ae_val_targets = prepare_ae_frame(normal_val_df)
ae_test_inputs, ae_test_targets = prepare_ae_frame(test_df)

# %%
# Inputs
numeric_input = layers.Input(shape=(len(numeric_cols),), name="numeric")
model_inputs = {"numeric": numeric_input}
parts = [numeric_input]

for col in categorical_cols:
    inp = layers.Input(shape=(), dtype="int32", name=col)
    model_inputs[col] = inp
    emb_dim = min(8, max(2, int(np.ceil(np.sqrt(category_sizes[col])))))
    emb = layers.Embedding(category_sizes[col], emb_dim, name=f"{col}_embedding")(inp)
    parts.append(layers.Flatten()(emb))

combined = layers.Concatenate(name="combined_features")(parts)
hidden = layers.Dense(32, activation="relu")(combined)
latent = layers.Dense(8, activation="relu", name="behavior_embedding")(hidden)
decoded = layers.Dense(32, activation="relu")(latent)

outputs = {
    "numeric_out": layers.Dense(len(numeric_cols), name="numeric_out")(decoded)
}
for col in categorical_cols:
    outputs[f"{col}_out"] = layers.Dense(
        category_sizes[col], activation="softmax", name=f"{col}_out"
    )(decoded)

autoencoder = keras.Model(inputs=model_inputs, outputs=outputs)
encoder = keras.Model(inputs=model_inputs, outputs=latent)

losses = {"numeric_out": "mse"}
loss_weights = {"numeric_out": 1.0}
for col in categorical_cols:
    losses[f"{col}_out"] = "sparse_categorical_crossentropy"
    loss_weights[f"{col}_out"] = 0.35

autoencoder.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss=losses,
    loss_weights=loss_weights
)
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ user (InputLayer)   │ (None)            │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ country             │ (None)            │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ device (InputLayer) │ (None)            │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ protocol            │ (None)            │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ user_embedding      │ (None, 3)         │         18 │ user[0][0]        │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ country_embedding   │ (None, 3)         │         21 │ country[0][0]     │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ device_embedding    │ (None, 3)         │         21 │ device[0][0]      │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ protocol_embedding  │ (None, 2)         │          8 │ protocol[0][0]    │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ numeric             │ (None, 5)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 3)         │          0 │ user_embedding[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 3)         │          0 │ country_embeddin… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 3)         │          0 │ device_embedding… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_3 (Flatten) │ (None, 2)         │          0 │ protocol_embeddi… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ combined_features   │ (None, 16)        │          0 │ numeric[0][0],    │
# │ (Concatenate)       │                   │            │ flatten[0][0],    │
# │                     │                   │            │ flatten_1[0][0],  │
# │                     │                   │            │ flatten_2[0][0],  │
# │                     │                   │            │ flatten_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 32)        │        544 │ combined_feature… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ behavior_embedding  │ (None, 8)         │        264 │ dense[0][0]       │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 32)        │        288 │ behavior_embeddi… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ country_out (Dense) │ (None, 7)         │        231 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ device_out (Dense)  │ (None, 7)         │        231 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ numeric_out (Dense) │ (None, 5)         │        165 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ protocol_out        │ (None, 4)         │        132 │ dense_1[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ user_out (Dense)    │ (None, 6)         │        198 │ dense_1[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,121 (8.29 KB)
#  Trainable params: 2,121 (8.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=5, restore_best_weights=True
    )
]

history = autoencoder.fit(
    ae_train_inputs,
    ae_train_targets,
    validation_data=(ae_val_inputs, ae_val_targets),
    epochs=50,
    batch_size=128,
    callbacks=callbacks,
    verbose=1
)

plt.plot(history.history["loss"], label="train")
plt.plot(history.history["val_loss"], label="validation")
plt.xlabel("Epoch")
plt.ylabel("Combined reconstruction loss")
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - country_out_loss: 1.8497 - device_out_loss: 1.9146 - loss: 3.4086 - numeric_out_loss: 0.9768 - protocol_out_loss: 1.4174 - user_out_loss: 1.7662 - val_country_out_loss: 1.7627 - val_device_out_loss: 1.8672 - val_loss: 3.3641 - val_numeric_out_loss: 0.9915 - val_protocol_out_loss: 1.3935 - val_user_out_loss: 1.7554
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 1.6595 - device_out_loss: 1.8078 - loss: 3.2010 - numeric_out_loss: 0.8984 - protocol_out_loss: 1.3721 - user_out_loss: 1.7394 - val_country_out_loss: 1.5137 - val_device_out_loss: 1.7388 - val_loss: 3.1252 - val_numeric_out_loss: 0.9143 - val_protocol_out_loss: 1.3416 - val_user_out_loss: 1.7227
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - country_out_loss: 1.3399 - device_out_loss: 1.6406 - loss: 2.9184 - numeric_out_loss: 0.8210 - protocol_out_loss: 1.3128 - user_out_loss: 1.6993 - val_country_out_loss: 1.0939 - val_device_out_loss: 1.5253 - val_loss: 2.7645 - val_numeric_out_loss: 0.8206 - val_protocol_out_loss: 1.2577 - val_user_out_loss: 1.6771
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - country_out_loss: 0.8422 - device_out_loss: 1.3806 - loss: 2.4936 - numeric_out_loss: 0.7108 - protocol_out_loss: 1.2195 - user_out_loss: 1.6515 - val_country_out_loss: 0.5281 - val_device_out_loss: 1.2370 - val_loss: 2.2671 - val_numeric_out_loss: 0.6871 - val_protocol_out_loss: 1.1183 - val_user_out_loss: 1.6309
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 0.3298 - device_out_loss: 1.1061 - loss: 2.0144 - numeric_out_loss: 0.5665 - protocol_out_loss: 1.0831 - user_out_loss: 1.6178 - val_country_out_loss: 0.1439 - val_device_out_loss: 1.0429 - val_loss: 1.8436 - val_numeric_out_loss: 0.5330 - val_protocol_out_loss: 0.9473 - val_user_out_loss: 1.6104
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - country_out_loss: 0.0874 - device_out_loss: 0.9603 - loss: 1.6958 - numeric_out_loss: 0.4280 - protocol_out_loss: 0.9776 - user_out_loss: 1.5968 - val_country_out_loss: 0.0401 - val_device_out_loss: 0.9541 - val_loss: 1.6006 - val_numeric_out_loss: 0.3872 - val_protocol_out_loss: 0.8815 - val_user_out_loss: 1.5911
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 0.0312 - device_out_loss: 0.8857 - loss: 1.5015 - numeric_out_loss: 0.2989 - protocol_out_loss: 0.9415 - user_out_loss: 1.5776 - val_country_out_loss: 0.0173 - val_device_out_loss: 0.8886 - val_loss: 1.4210 - val_numeric_out_loss: 0.2545 - val_protocol_out_loss: 0.8495 - val_user_out_loss: 1.5775
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - country_out_loss: 0.0155 - device_out_loss: 0.8402 - loss: 1.3562 - numeric_out_loss: 0.1893 - protocol_out_loss: 0.9138 - user_out_loss: 1.5644 - val_country_out_loss: 0.0090 - val_device_out_loss: 0.8481 - val_loss: 1.2887 - val_numeric_out_loss: 0.1526 - val_protocol_out_loss: 0.8270 - val_user_out_loss: 1.5619
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 0.0092 - device_out_loss: 0.7987 - loss: 1.2499 - numeric_out_loss: 0.1152 - protocol_out_loss: 0.8926 - user_out_loss: 1.5414 - val_country_out_loss: 0.0056 - val_device_out_loss: 0.7965 - val_loss: 1.1944 - val_numeric_out_loss: 0.0943 - val_protocol_out_loss: 0.8062 - val_user_out_loss: 1.5350
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - country_out_loss: 0.0068 - device_out_loss: 0.7414 - loss: 1.1638 - numeric_out_loss: 0.0722 - protocol_out_loss: 0.8665 - user_out_loss: 1.5042 - val_country_out_loss: 0.0042 - val_device_out_loss: 0.7306 - val_loss: 1.1197 - val_numeric_out_loss: 0.0658 - val_protocol_out_loss: 0.7828 - val_user_out_loss: 1.4935
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 0.0058 - device_out_loss: 0.6649 - loss: 1.0934 - numeric_out_loss: 0.0573 - protocol_out_loss: 0.8372 - user_out_loss: 1.4522 - val_country_out_loss: 0.0039 - val_device_out_loss: 0.6357 - val_loss: 1.0484 - val_numeric_out_loss: 0.0616 - val_protocol_out_loss: 0.7516 - val_user_out_loss: 1.4282
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 0.0051 - device_out_loss: 0.5575 - loss: 1.0133 - numeric_out_loss: 0.0585 - protocol_out_loss: 0.7982 - user_out_loss: 1.3672 - val_country_out_loss: 0.0033 - val_device_out_loss: 0.5106 - val_loss: 0.9566 - val_numeric_out_loss: 0.0641 - val_protocol_out_loss: 0.7089 - val_user_out_loss: 1.3274
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - country_out_loss: 0.0038 - device_out_loss: 0.4292 - loss: 0.9138 - numeric_out_loss: 0.0613 - protocol_out_loss: 0.7508 - user_out_loss: 1.2518 - val_country_out_loss: 0.0019 - val_device_out_loss: 0.3788 - val_loss: 0.8485 - val_numeric_out_loss: 0.0640 - val_protocol_out_loss: 0.6673 - val_user_out_loss: 1.1935
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 0.0020 - device_out_loss: 0.3202 - loss: 0.8189 - numeric_out_loss: 0.0609 - protocol_out_loss: 0.7169 - user_out_loss: 1.1267 - val_country_out_loss: 9.2910e-04 - val_device_out_loss: 0.2911 - val_loss: 0.7658 - val_numeric_out_loss: 0.0640 - val_protocol_out_loss: 0.6349 - val_user_out_loss: 1.0783
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - country_out_loss: 9.9248e-04 - device_out_loss: 0.2582 - loss: 0.7506 - numeric_out_loss: 0.0592 - protocol_out_loss: 0.6764 - user_out_loss: 1.0398 - val_country_out_loss: 5.1177e-04 - val_device_out_loss: 0.2504 - val_loss: 0.7072 - val_numeric_out_loss: 0.0610 - val_protocol_out_loss: 0.5834 - val_user_out_loss: 1.0118
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 6.2208e-04 - device_out_loss: 0.2290 - loss: 0.7006 - numeric_out_loss: 0.0557 - protocol_out_loss: 0.6180 - user_out_loss: 0.9951 - val_country_out_loss: 3.3296e-04 - val_device_out_loss: 0.2299 - val_loss: 0.6652 - val_numeric_out_loss: 0.0575 - val_protocol_out_loss: 0.5270 - val_user_out_loss: 0.9788
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - country_out_loss: 4.4640e-04 - device_out_loss: 0.2090 - loss: 0.6604 - numeric_out_loss: 0.0519 - protocol_out_loss: 0.5669 - user_out_loss: 0.9624 - val_country_out_loss: 2.6303e-04 - val_device_out_loss: 0.2053 - val_loss: 0.6276 - val_numeric_out_loss: 0.0548 - val_protocol_out_loss: 0.4858 - val_user_out_loss: 0.9452
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 3.9452e-04 - device_out_loss: 0.1874 - loss: 0.6239 - numeric_out_loss: 0.0496 - protocol_out_loss: 0.5198 - user_out_loss: 0.9334 - val_country_out_loss: 2.2348e-04 - val_device_out_loss: 0.1830 - val_loss: 0.5917 - val_numeric_out_loss: 0.0529 - val_protocol_out_loss: 0.4411 - val_user_out_loss: 0.9153
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - country_out_loss: 3.2712e-04 - device_out_loss: 0.1612 - loss: 0.5852 - numeric_out_loss: 0.0470 - protocol_out_loss: 0.4749 - user_out_loss: 0.9015 - val_country_out_loss: 2.0452e-04 - val_device_out_loss: 0.1534 - val_loss: 0.5543 - val_numeric_out_loss: 0.0497 - val_protocol_out_loss: 0.4003 - val_user_out_loss: 0.8878
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - country_out_loss: 2.8330e-04 - device_out_loss: 0.1355 - loss: 0.5437 - numeric_out_loss: 0.0442 - protocol_out_loss: 0.4215 - user_out_loss: 0.8700 - val_country_out_loss: 1.5311e-04 - val_device_out_loss: 0.1299 - val_loss: 0.5097 - val_numeric_out_loss: 0.0463 - val_protocol_out_loss: 0.3423 - val_user_out_loss: 0.8516
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - country_out_loss: 1.9189e-04 - device_out_loss: 0.1107 - loss: 0.5000 - numeric_out_loss: 0.0404 - protocol_out_loss: 0.3636 - user_out_loss: 0.8386 - val_country_out_loss: 1.0231e-04 - val_device_out_loss: 0.1005 - val_loss: 0.4638 - val_numeric_out_loss: 0.0393 - val_protocol_out_loss: 0.2905 - val_user_out_loss: 0.8218
# Epoch 22/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - country_out_loss: 1.1215e-04 - device_out_loss: 0.0849 - loss: 0.4534 - numeric_out_loss: 0.0353 - protocol_out_loss: 0.3050 - user_out_loss: 0.8044 - val_country_out_loss: 5.1909e-05 - val_device_out_loss: 0.0772 - val_loss: 0.4224 - val_numeric_out_loss: 0.0345 - val_protocol_out_loss: 0.2471 - val_user_out_loss: 0.7840
# Epoch 23/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - country_out_loss: 5.2562e-05 - device_out_loss: 0.0618 - loss: 0.4131 - numeric_out_loss: 0.0312 - protocol_out_loss: 0.2580 - user_out_loss: 0.7713 - val_country_out_loss: 2.5023e-05 - val_device_out_loss: 0.0549 - val_loss: 0.3851 - val_numeric_out_loss: 0.0313 - val_protocol_out_loss: 0.2099 - val_user_out_loss: 0.7462
# Epoch 24/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - country_out_loss: 2.4482e-05 - device_out_loss: 0.0449 - loss: 0.3804 - numeric_out_loss: 0.0267 - protocol_out_loss: 0.2245 - user_out_loss: 0.7413 - val_country_out_loss: 9.1836e-06 - val_device_out_loss: 0.0414 - val_loss: 0.3545 - val_numeric_out_loss: 0.0262 - val_protocol_out_loss: 0.1813 - val_user_out_loss: 0.7152
# Epoch 25/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - country_out_loss: 9.5380e-06 - device_out_loss: 0.0327 - loss: 0.3497 - numeric_out_loss: 0.0230 - protocol_out_loss: 0.1948 - user_out_loss: 0.7058 - val_country_out_loss: 4.1382e-06 - val_device_out_loss: 0.0299 - val_loss: 0.3308 - val_numeric_out_loss: 0.0233 - val_protocol_out_loss: 0.1651 - val_user_out_loss: 0.6836
# Epoch 26/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - country_out_loss: 4.1645e-06 - device_out_loss: 0.0245 - loss: 0.3235 - numeric_out_loss: 0.0200 - protocol_out_loss: 0.1717 - user_out_loss: 0.6708 - val_country_out_loss: 1.4950e-06 - val_device_out_loss: 0.0241 - val_loss: 0.3001 - val_numeric_out_loss: 0.0200 - val_protocol_out_loss: 0.1412 - val_user_out_loss: 0.6351
# Epoch 27/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - country_out_loss: 1.5162e-06 - device_out_loss: 0.0204 - loss: 0.2925 - numeric_out_loss: 0.0177 - protocol_out_loss: 0.1530 - user_out_loss: 0.6116 - val_country_out_loss: 5.5801e-07 - val_device_out_loss: 0.0196 - val_loss: 0.2695 - val_numeric_out_loss: 0.0175 - val_protocol_out_loss: 0.1242 - val_user_out_loss: 0.5761
# Epoch 28/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 5.8918e-07 - device_out_loss: 0.0169 - loss: 0.2554 - numeric_out_loss: 0.0155 - protocol_out_loss: 0.1329 - user_out_loss: 0.5355 - val_country_out_loss: 2.4728e-07 - val_device_out_loss: 0.0164 - val_loss: 0.2326 - val_numeric_out_loss: 0.0157 - val_protocol_out_loss: 0.1080 - val_user_out_loss: 0.4952
# Epoch 29/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 2.4302e-07 - device_out_loss: 0.0135 - loss: 0.2189 - numeric_out_loss: 0.0138 - protocol_out_loss: 0.1147 - user_out_loss: 0.4576 - val_country_out_loss: 1.5544e-07 - val_device_out_loss: 0.0141 - val_loss: 0.2020 - val_numeric_out_loss: 0.0141 - val_protocol_out_loss: 0.0928 - val_user_out_loss: 0.4299
# Epoch 30/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 1.5299e-07 - device_out_loss: 0.0106 - loss: 0.1899 - numeric_out_loss: 0.0126 - protocol_out_loss: 0.0956 - user_out_loss: 0.4005 - val_country_out_loss: 1.2815e-07 - val_device_out_loss: 0.0119 - val_loss: 0.1833 - val_numeric_out_loss: 0.0143 - val_protocol_out_loss: 0.0780 - val_user_out_loss: 0.3929
# Epoch 31/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - country_out_loss: 1.2637e-07 - device_out_loss: 0.0085 - loss: 0.1697 - numeric_out_loss: 0.0128 - protocol_out_loss: 0.0782 - user_out_loss: 0.3616 - val_country_out_loss: 1.2070e-07 - val_device_out_loss: 0.0107 - val_loss: 0.1602 - val_numeric_out_loss: 0.0132 - val_protocol_out_loss: 0.0639 - val_user_out_loss: 0.3452
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 1.2036e-07 - device_out_loss: 0.0071 - loss: 0.1481 - numeric_out_loss: 0.0116 - protocol_out_loss: 0.0641 - user_out_loss: 0.3187 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0095 - val_loss: 0.1432 - val_numeric_out_loss: 0.0139 - val_protocol_out_loss: 0.0524 - val_user_out_loss: 0.3074
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 1.1926e-07 - device_out_loss: 0.0057 - loss: 0.1297 - numeric_out_loss: 0.0130 - protocol_out_loss: 0.0529 - user_out_loss: 0.2747 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0083 - val_loss: 0.1215 - val_numeric_out_loss: 0.0150 - val_protocol_out_loss: 0.0423 - val_user_out_loss: 0.2536
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - country_out_loss: 1.1921e-07 - device_out_loss: 0.0048 - loss: 0.1080 - numeric_out_loss: 0.0130 - protocol_out_loss: 0.0424 - user_out_loss: 0.2244 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0076 - val_loss: 0.1007 - val_numeric_out_loss: 0.0143 - val_protocol_out_loss: 0.0360 - val_user_out_loss: 0.2033
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 1.1921e-07 - device_out_loss: 0.0040 - loss: 0.0893 - numeric_out_loss: 0.0120 - protocol_out_loss: 0.0357 - user_out_loss: 0.1811 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0068 - val_loss: 0.0821 - val_numeric_out_loss: 0.0132 - val_protocol_out_loss: 0.0295 - val_user_out_loss: 0.1605
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 1.1921e-07 - device_out_loss: 0.0035 - loss: 0.0710 - numeric_out_loss: 0.0104 - protocol_out_loss: 0.0299 - user_out_loss: 0.1395 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0063 - val_loss: 0.0660 - val_numeric_out_loss: 0.0121 - val_protocol_out_loss: 0.0249 - val_user_out_loss: 0.1230
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 1.1921e-07 - device_out_loss: 0.0030 - loss: 0.0567 - numeric_out_loss: 0.0095 - protocol_out_loss: 0.0254 - user_out_loss: 0.1063 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0059 - val_loss: 0.0532 - val_numeric_out_loss: 0.0103 - val_protocol_out_loss: 0.0211 - val_user_out_loss: 0.0956
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 1.1921e-07 - device_out_loss: 0.0026 - loss: 0.0464 - numeric_out_loss: 0.0082 - protocol_out_loss: 0.0218 - user_out_loss: 0.0847 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0056 - val_loss: 0.0447 - val_numeric_out_loss: 0.0094 - val_protocol_out_loss: 0.0183 - val_user_out_loss: 0.0770
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - country_out_loss: 1.1921e-07 - device_out_loss: 0.0023 - loss: 0.0388 - numeric_out_loss: 0.0073 - protocol_out_loss: 0.0190 - user_out_loss: 0.0687 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0053 - val_loss: 0.0393 - val_numeric_out_loss: 0.0096 - val_protocol_out_loss: 0.0159 - val_user_out_loss: 0.0637
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 1.1921e-07 - device_out_loss: 0.0020 - loss: 0.0325 - numeric_out_loss: 0.0063 - protocol_out_loss: 0.0164 - user_out_loss: 0.0565 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0050 - val_loss: 0.0335 - val_numeric_out_loss: 0.0081 - val_protocol_out_loss: 0.0143 - val_user_out_loss: 0.0535
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - country_out_loss: 1.1921e-07 - device_out_loss: 0.0017 - loss: 0.0280 - numeric_out_loss: 0.0057 - protocol_out_loss: 0.0144 - user_out_loss: 0.0477 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0048 - val_loss: 0.0299 - val_numeric_out_loss: 0.0078 - val_protocol_out_loss: 0.0122 - val_user_out_loss: 0.0460
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 1.1921e-07 - device_out_loss: 0.0015 - loss: 0.0248 - numeric_out_loss: 0.0057 - protocol_out_loss: 0.0127 - user_out_loss: 0.0405 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0046 - val_loss: 0.0266 - val_numeric_out_loss: 0.0071 - val_protocol_out_loss: 0.0111 - val_user_out_loss: 0.0400
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 1.1921e-07 - device_out_loss: 0.0013 - loss: 0.0220 - numeric_out_loss: 0.0052 - protocol_out_loss: 0.0114 - user_out_loss: 0.0352 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0046 - val_loss: 0.0239 - val_numeric_out_loss: 0.0066 - val_protocol_out_loss: 0.0097 - val_user_out_loss: 0.0352
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 1.1921e-07 - device_out_loss: 0.0012 - loss: 0.0189 - numeric_out_loss: 0.0042 - protocol_out_loss: 0.0101 - user_out_loss: 0.0308 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0044 - val_loss: 0.0219 - val_numeric_out_loss: 0.0062 - val_protocol_out_loss: 0.0088 - val_user_out_loss: 0.0316
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 1.1921e-07 - device_out_loss: 9.9730e-04 - loss: 0.0171 - numeric_out_loss: 0.0040 - protocol_out_loss: 0.0091 - user_out_loss: 0.0273 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0043 - val_loss: 0.0200 - val_numeric_out_loss: 0.0057 - val_protocol_out_loss: 0.0080 - val_user_out_loss: 0.0283
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - country_out_loss: 1.1921e-07 - device_out_loss: 8.9547e-04 - loss: 0.0153 - numeric_out_loss: 0.0037 - protocol_out_loss: 0.0082 - user_out_loss: 0.0242 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0043 - val_loss: 0.0188 - val_numeric_out_loss: 0.0058 - val_protocol_out_loss: 0.0071 - val_user_out_loss: 0.0256
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - country_out_loss: 1.1921e-07 - device_out_loss: 8.0715e-04 - loss: 0.0143 - numeric_out_loss: 0.0038 - protocol_out_loss: 0.0074 - user_out_loss: 0.0218 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0043 - val_loss: 0.0172 - val_numeric_out_loss: 0.0052 - val_protocol_out_loss: 0.0066 - val_user_out_loss: 0.0233
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 1.1921e-07 - device_out_loss: 7.3268e-04 - loss: 0.0128 - numeric_out_loss: 0.0033 - protocol_out_loss: 0.0068 - user_out_loss: 0.0195 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0041 - val_loss: 0.0159 - val_numeric_out_loss: 0.0048 - val_protocol_out_loss: 0.0060 - val_user_out_loss: 0.0214
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 1.1921e-07 - device_out_loss: 6.6323e-04 - loss: 0.0116 - numeric_out_loss: 0.0029 - protocol_out_loss: 0.0063 - user_out_loss: 0.0177 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0041 - val_loss: 0.0149 - val_numeric_out_loss: 0.0047 - val_protocol_out_loss: 0.0055 - val_user_out_loss: 0.0198
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - country_out_loss: 1.1921e-07 - device_out_loss: 6.0173e-04 - loss: 0.0107 - numeric_out_loss: 0.0028 - protocol_out_loss: 0.0058 - user_out_loss: 0.0162 - val_country_out_loss: 1.1921e-07 - val_device_out_loss: 0.0042 - val_loss: 0.0143 - val_numeric_out_loss: 0.0045 - val_protocol_out_loss: 0.0052 - val_user_out_loss: 0.0185

# %% [markdown]
# ### Interpreting the training curve
#
# Compare the training and validation reconstruction losses:
#
# - Both curves decreasing suggests that the autoencoder is learning regular behavior.
# - A validation curve that stops improving while training loss continues to fall indicates possible overfitting.
# - A large persistent gap between the curves suggests that the model may not generalize well to unseen normal behavior.
# - Early stopping restores the weights from the best validation epoch, so the final model is not necessarily the model from the last displayed epoch.
#
# The absolute loss value is less important than stable convergence and similar behavior on the training and validation sets.

# %%
def ae_anomaly_scores(model, inputs, targets):
    predictions = model.predict(inputs, verbose=0)
    numeric_error = np.mean(
        np.square(targets["numeric_out"] - predictions["numeric_out"]), axis=1
    )

    categorical_error = np.zeros(len(numeric_error), dtype="float32")
    eps = 1e-8
    for col in categorical_cols:
        true_idx = targets[f"{col}_out"].astype(int)
        probs = predictions[f"{col}_out"]
        categorical_error += -np.log(probs[np.arange(len(true_idx)), true_idx] + eps)

    categorical_error /= len(categorical_cols)
    return numeric_error + 0.35 * categorical_error

normal_val_score = ae_anomaly_scores(autoencoder, ae_val_inputs, ae_val_targets)
ae_score = ae_anomaly_scores(autoencoder, ae_test_inputs, ae_test_targets)

threshold = np.percentile(normal_val_score, 99)
ae_pred = (ae_score > threshold).astype(int)

print("AE threshold:", threshold)
print(confusion_matrix(y_test, ae_pred))
print(classification_report(y_test, ae_pred, target_names=["Normal", "Attack"]))
# Out:
# AE threshold: 0.042095568
# [[753   7]
#  [  0  32]]
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00       760
#       Attack       0.82      1.00      0.90        32
#
#     accuracy                           0.99       792
#    macro avg       0.91      1.00      0.95       792
# weighted avg       0.99      0.99      0.99       792

# %% [markdown]
# ### Reading the autoencoder output
#
# The autoencoder is trained only on normal events. It assigns a high anomaly score when it reconstructs an event poorly.
#
# The score combines:
#
# - numeric reconstruction error; and
# - categorical reconstruction surprise from user, country, device, and protocol.
#
# The threshold is the 99th percentile of reconstruction scores from normal validation events. Therefore, approximately 1% of validation-normal behavior is expected to exceed the threshold even without an attack.
#
# Interpretation:
#
# - **High recall with low precision:** sensitive detector, but many unnecessary alerts.
# - **High precision with low recall:** conservative detector that misses more attacks.
# - **Many false positives:** threshold may be too low or normal behavior may be diverse.
# - **Many false negatives:** threshold may be too high or attacks may resemble normal behavior.
#
# Changing the percentile directly changes the operational trade-off: lower percentiles raise more alerts; higher percentiles raise fewer alerts.

# %% [markdown]
# ## 6. Quantitative comparison

# %%
def metric_row(name, pred):
    precision, recall, f1, _ = precision_recall_fscore_support(
        y_test, pred, average="binary", zero_division=0
    )
    cm = confusion_matrix(y_test, pred)
    tn, fp, fn, tp = cm.ravel()
    return {
        "model": name,
        "detected_anomalies": int(pred.sum()),
        "precision": precision,
        "recall": recall,
        "f1": f1,
        "false_positives": int(fp),
        "false_negatives": int(fn)
    }

comparison = pd.DataFrame([
    metric_row("Isolation Forest", if_pred),
    metric_row("Autoencoder + embeddings", ae_pred)
]).set_index("model")

display(comparison.round(3))

agreement = np.mean(if_pred == ae_pred)
print(f"Agreement rate: {agreement:.2%}")
print("Both:", int(np.sum((if_pred == 1) & (ae_pred == 1))))
print("Isolation Forest only:", int(np.sum((if_pred == 1) & (ae_pred == 0))))
print("Autoencoder only:", int(np.sum((if_pred == 0) & (ae_pred == 1))))
# Out:
#                           detected_anomalies  precision  recall     f1  \
# model
# Isolation Forest                          33      0.970     1.0  0.985
# Autoencoder + embeddings                  39      0.821     1.0  0.901
#
#                           false_positives  false_negatives
# model
# Isolation Forest                        1                0
# Autoencoder + embeddings                7                0
# Agreement rate: 99.24%
# Both: 33
# Isolation Forest only: 0
# Autoencoder only: 6

# %% [markdown]
# ### How to compare the two methods
#
# Use the table to answer different operational questions rather than declaring one universal winner:
#
# - Prefer higher **recall** when missing an attack is the greatest risk.
# - Prefer higher **precision** when analyst workload and alert fatigue are the main constraints.
# - Prefer higher **F1** when precision and recall are equally important.
# - Compare **false positives** and **false negatives** directly because they represent different operational costs.
#
# The agreement statistics indicate complementarity:
#
# - **Both models:** strongest candidates for analyst review.
# - **Isolation Forest only:** globally isolated observations that the autoencoder reconstructed acceptably.
# - **Autoencoder only:** observations that violate learned behavioral relationships even if no single feature is extreme.
#
# A high agreement rate does not automatically mean better detection; it only means that the models often make the same decision.

# %%
# Automatic interpretation of the comparison table
best_precision = comparison["precision"].idxmax()
best_recall = comparison["recall"].idxmax()
best_f1 = comparison["f1"].idxmax()
fewest_fp = comparison["false_positives"].idxmin()
fewest_fn = comparison["false_negatives"].idxmin()

print("RESULT INTERPRETATION")
print("- Highest precision:", best_precision)
print("- Highest recall:", best_recall)
print("- Highest F1:", best_f1)
print("- Fewest false positives:", fewest_fp)
print("- Fewest false negatives:", fewest_fn)

if best_precision == best_recall == best_f1:
    print(f"\n{best_f1} is strongest on the main summary metrics for this run.")
else:
    print("\nNo single model dominates every criterion. Select a model according to the operational cost of false alerts versus missed attacks.")

print("\nRecommended triage rule:")
print("1. Prioritize events detected by both models.")
print("2. Review model-disagreement events manually.")
print("3. Treat events rejected by both as lower priority, not guaranteed benign.")
# Out:
# RESULT INTERPRETATION
# - Highest precision: Isolation Forest
# - Highest recall: Isolation Forest
# - Highest F1: Isolation Forest
# - Fewest false positives: Isolation Forest
# - Fewest false negatives: Isolation Forest
#
# Isolation Forest is strongest on the main summary metrics for this run.
#
# Recommended triage rule:
# 1. Prioritize events detected by both models.
# 2. Review model-disagreement events manually.
# 3. Treat events rejected by both as lower priority, not guaranteed benign.

# %% [markdown]
# ## 7. Original feature space versus behavioral embedding space

# %%
# PCA of Isolation Forest input space
pca_original = PCA(n_components=2, random_state=SEED)
xy_original = pca_original.fit_transform(X_if_test)

# PCA of learned latent behavioral embeddings
latent_vectors = encoder.predict(ae_test_inputs, verbose=0)
pca_latent = PCA(n_components=2, random_state=SEED)
xy_latent = pca_latent.fit_transform(latent_vectors)

plt.figure(figsize=(9, 6))
plt.scatter(xy_original[:, 0], xy_original[:, 1], c=y_test, s=14, alpha=0.65)
plt.title("PCA of preprocessed input features — color = ground truth")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

plt.figure(figsize=(9, 6))
plt.scatter(xy_latent[:, 0], xy_latent[:, 1], c=y_test, s=14, alpha=0.65)
plt.title("PCA of autoencoder behavioral embeddings — color = ground truth")
plt.xlabel("Latent PC1")
plt.ylabel("Latent PC2")
plt.show()

# %% [markdown]
# ### Interpreting the PCA visualizations
#
# PCA compresses a high-dimensional representation into two dimensions. Therefore, these plots are diagnostic aids rather than proof of model quality.
#
# - Clear separation between normal and attack points suggests that the representation contains useful anomaly structure.
# - Overlap is expected because two principal components discard information.
# - Better separation in the latent plot suggests that the autoencoder has learned a useful behavioral representation.
# - Poor separation in the latent plot does not necessarily mean poor detection because the anomaly score is based on reconstruction error, not PCA distance.
#
# Use the quantitative metrics as the primary evaluation and the plots to explain patterns.

# %% [markdown]
# ## 8. Inspect model disagreements

# %%
results = test_df.copy()
results["if_score"] = if_score
results["if_pred"] = if_pred
results["ae_score"] = ae_score
results["ae_pred"] = ae_pred
results["models_agree"] = results["if_pred"] == results["ae_pred"]

disagreements = results[~results["models_agree"]].copy()
display(disagreements.sort_values(["ae_score", "if_score"], ascending=False).head(15))
# Out:
#              user country                 device protocol  hour  \
# 870       admin01      IL      admin_workstation      VPN    16
# 2688      admin01      IL      admin_workstation    HTTPS     9
# 372     analyst02      IL         managed_laptop    HTTPS    10
# 551   developer01      IL  developer_workstation      VPN    13
# 2975  developer01      IL  developer_workstation    HTTPS    11
# 1525      admin01      IL      admin_workstation    HTTPS    11
#
#       failed_attempts  distance_km  session_minutes  bytes_out_mb  is_attack  \
# 870                 0     4.156354        12.158062      3.901917          0
# 2688                0    22.362931        93.213104      4.188047          0
# 372                 1    31.692761        13.494365     40.451243          0
# 551                 1    54.232778        62.229233     10.922608          0
# 2975                2     0.642864        23.068715     25.930824          0
# 1525                0    12.008422        95.405185     17.784734          0
#
#       if_score  if_pred  ae_score  ae_pred  models_agree
# 870  -0.062123        0  0.170875        1         False
# 2688 -0.067464        0  0.068139        1         False
# 372  -0.100038        0  0.066152        1         False
# 551  -0.081340        0  0.060898        1         False
# 2975 -0.091810        0  0.047697        1         False
# 1525 -0.068373        0  0.044000        1         False

# %% [markdown]
# ### How to investigate disagreements
#
# Disagreement records are the most informative cases for comparing the models.
#
# For **Isolation Forest only** alerts, check whether one or more original features are extreme. The event may be globally isolated even though the autoencoder can reconstruct its overall pattern.
#
# For **autoencoder only** alerts, check whether the event contains an unusual relationship such as:
#
# - a familiar user with an unfamiliar device;
# - a normal login hour from an unusual country;
# - individually moderate values that form an abnormal behavioral combination.
#
# For each disagreement, record:
#
# 1. which model raised the alert;
# 2. the strongest supporting evidence;
# 3. whether the event appears malicious, unusual but legitimate, or inconclusive;
# 4. whether an analyst should escalate, request more evidence, or close the alert.
#
# Do not assume that either model is automatically correct. Ground truth is available here for evaluation, but in a real SOC the disagreement would require investigation.

# %% [markdown]
# ## 9. Student interpretation
#
# Select at least three disagreement records and answer:
#
# 1. Which model raised the alert?
# 2. What evidence supports the alert?
# 3. Could the event be a legitimate exception?
# 4. Would you accept, challenge, or escalate the alert?
# 5. Which MITRE ATT&CK technique is most relevant?
#
# ## 10. Conclusion
#
# Compare the models in terms of:
#
# - precision and recall;
# - false positives and false negatives;
# - anomaly types detected;
# - usefulness of behavioral embeddings;
# - limitations of training only on synthetic or incomplete normal data.
